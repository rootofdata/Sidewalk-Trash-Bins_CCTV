# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

# %%
import pandas as pd
df1 = pd.read_excel('C:/Users/dudtj/OneDrive - 숭실대학교 - Soongsil University/Desktop/CL/python/강서구 경진대회/data/공모전 데이터 모음/서울특별시 강서구_가로쓰레기통 설치 정보_20210901.xlsx')
df2 = pd.read_excel('C:/Users/dudtj/OneDrive - 숭실대학교 - Soongsil University/Desktop/CL/python/강서구 경진대회/data/공모전 데이터 모음/강서구 생활인구(2020 1분기~2021 3분기 동정보포함).xlsx')

# %%
#글씨설정
plt.rc("font",family="Malgun Gothic")
sns.set(font="Margun Gothic",rc={"axes.unicode_minus":False},style='darkgrid')
mpl.rc('font',family='Malgun Gothic')
plt.rcParams['axes.unicode_minus']=False

#맷플롯립 한글 설정
font_path = r'C:\Users\dudtj\OneDrive\Desktop\금융데이터\NanumFontSetup_TTF_ALL'
fontprop = fm.FontProperties(fname=font_path, size=18)

# %%
df1.head()
# Out:
#    연번       자치구명 도로(가로)명  설치위치              세부위치   설치지점    수거 쓰레기 종류      형태  \
# 0   1  서울특별시 강서구   가로공원로  화곡1동      나누리병원 16-199  버스정류장   일반쓰레기 수거용   일반쓰레기통
# 1   2  서울특별시 강서구   가로공원로  화곡1동      나누리병원 16-200  버스정류장   일반쓰레기 수거용   일반쓰레기통
# 2   3  서울특별시 강서구     강서로  화곡1동       까치산역 16-192  버스정류장   일반쓰레기 수거용   일반쓰레기통
# 3   4  서울특별시 강서구     강서로  화곡1동       까치산역 16-192  버스정류장      재활용수거    일반쓰레기통
# 4   5  서울특별시 강서구     강서로  화곡1동  화곡역.현대주유소 16-205  버스정류장   일반쓰레기 수거용   일반쓰레기통
#
#         담당자 연락처
# 0  02-2600-4067
# 1  02-2600-4067
# 2  02-2600-4067
# 3  02-2600-4067
# 4  02-2600-4067

# %%
df2.head()
# Out:
#    기준 년코드  기준_분기_코드 상권_구분_코드  상권_구분_코드_명      상권_코드    상권_코드_명  총_생활인구_수  \
# 0  2020.0       4.0        A        골목상권  1000552.0  가로공원로76가길  632563.0
# 1  2020.0       3.0        A        골목상권  1000552.0  가로공원로76가길  703492.0
# 2  2021.0       3.0        A        골목상권  1000552.0  가로공원로76가길  525757.0
# 3  2020.0       2.0        A        골목상권  1000552.0  가로공원로76가길  714248.0
# 4  2021.0       2.0        A        골목상권  1000552.0  가로공원로76가길  502344.0
#
#    동 정보 Unnamed: 8
# 0  화곡1동        NaN
# 1  화곡1동        NaN
# 2  화곡1동        NaN
# 3  화곡1동        NaN
# 4  화곡1동        NaN

# %%
groups = df1.groupby('설치위치')
data1=groups.count() #평균
data1=data1.reset_index()
data1=data1[['설치위치','연번']]
data1.columns=['동 정보','개수']
data1
# Out:
#     동 정보  개수
# 0   가양1동  51
# 1   가양2동  11
# 2   가양3동  15
# 3    공항동  24
# 4   등촌1동  10
# 5   등촌2동  12
# 6   등촌3동  16
# 7   발산1동  19
# 8   방화1동  16
# 9   방화2동  14
# 10  방화3동  10
# 11   염창동  16
# 12  우장산동  11
# 13  화곡1동  24
# 14  화곡2동   3
# 15  화곡3동   5
# 16  화곡4동   6
# 17  화곡6동  16
# 18  화곡8동   2
# 19  화곡본동   6

# %%
df3=df2[df2["기준 년코드"]==2021.0] #2021년
df3=df2[df2["기준_분기_코드"]==3]#df3은 21년,3분기 것만.
# Out:
#      기준 년코드  기준_분기_코드 상권_구분_코드  상권_구분_코드_명      상권_코드    상권_코드_명  총_생활인구_수  \
# 1    2020.0       3.0        A        골목상권  1000552.0  가로공원로76가길  703492.0
# 2    2021.0       3.0        A        골목상권  1000552.0  가로공원로76가길  525757.0
# 8    2020.0       3.0        A        골목상권  1000553.0   가로공원로80길  616225.0
# 9    2021.0       3.0        A        골목상권  1000553.0   가로공원로80길  353516.0
# 15   2021.0       3.0        D        발달상권  1001179.0       강서구청  957844.0
# ..      ...       ...      ...         ...        ...        ...       ...
# 464  2020.0       3.0        A        골목상권  1000608.0     화곡로64길  724921.0
# 470  2020.0       3.0        R        전통시장  1001412.0     화곡본동시장  186727.0
# 471  2021.0       3.0        R        전통시장  1001412.0     화곡본동시장  138995.0
# 477  2021.0       3.0        R        전통시장  1001409.0   화곡중앙골목시장  247475.0
# 478  2020.0       3.0        R        전통시장  1001409.0   화곡중앙골목시장  170845.0
#
#      동 정보 Unnamed: 8
# 1    화곡1동        NaN
# 2    화곡1동        NaN
# 8    화곡1동        NaN
# 9    화곡1동        NaN
# 15   화곡6동        NaN
# ..    ...        ...
# 464  등촌1동        NaN
# 470  화곡본동        NaN
# 471  화곡본동        NaN
# 477  화곡1동        NaN
# 478  화곡1동        NaN
#
# [138 rows x 9 columns]

# %%
groups = df2.groupby('동 정보')
data2=groups.mean() #평균
data2=data2.reset_index()
data2=data2[['동 정보','총_생활인구_수']]

# %%
df5 = pd.read_excel('C:/Users/dudtj/OneDrive - 숭실대학교 - Soongsil University/Desktop/CL/python/강서구 경진대회/data/공모전 데이터 모음/행정동코드_매핑정보_2018_1.xlsx')
df5
# Out:
#     통계청행정동코드  행자부행정동코드 시도명 시군구명  동 정보
# 0    1116051  11500510  서울  강서구   염창동
# 1    1116052  11500520  서울  강서구  등촌1동
# 2    1116053  11500530  서울  강서구  등촌2동
# 3    1116054  11500535  서울  강서구  등촌3동
# 4    1116055  11500590  서울  강서구  화곡본동
# 5    1116057  11500550  서울  강서구  화곡2동
# 6    1116058  11500560  서울  강서구  화곡3동
# 7    1116059  11500570  서울  강서구  화곡4동
# 8    1116061  11500591  서울  강서구  화곡6동
# 9    1116063  11500593  서울  강서구  화곡8동
# 10   1116064  11500603  서울  강서구  가양1동
# 11   1116065  11500604  서울  강서구  가양2동
# 12   1116066  11500605  서울  강서구  가양3동
# 13   1116067  11500611  서울  강서구  발산1동
# 14   1116069  11500620  서울  강서구   공항동
# 15   1116070  11500630  서울  강서구  방화1동
# 16   1116071  11500640  서울  강서구  방화2동
# 17   1116072  11500641  서울  강서구  방화3동
# 18   1116073  11500540  서울  강서구  화곡1동
# 19   1116074  11500615  서울  강서구  우장산동

# %%
last_df=pd.merge(data1,data2,on='동 정보')
last_df['개수/생활인구']=last_df['개수']/last_df['총_생활인구_수']*10000
last_df
# Out:
#     동 정보  개수      총_생활인구_수   개수/생활인구
# 0   가양1동  51  2.025333e+05  2.518105
# 1    공항동  24  6.389930e+05  0.375591
# 2   등촌1동  10  4.217219e+05  0.237123
# 3   등촌2동  12  6.320865e+05  0.189847
# 4   등촌3동  16  1.385180e+05  1.155085
# 5   발산1동  19  6.665132e+05  0.285066
# 6   방화1동  16  6.054130e+05  0.264282
# 7   방화2동  14  5.938310e+05  0.235757
# 8    염창동  16  7.947948e+05  0.201310
# 9   우장산동  11  7.938244e+05  0.138570
# 10  화곡1동  24  9.507398e+05  0.252435
# 11  화곡2동   3  6.888078e+05  0.043554
# 12  화곡3동   5  5.262232e+05  0.095017
# 13  화곡4동   6  6.107031e+05  0.098247
# 14  화곡6동  16  8.207713e+05  0.194939
# 15  화곡8동   2  1.008358e+06  0.019834
# 16  화곡본동   6  8.635931e+05  0.069477

# %%
df_code=pd.merge(last_df,df5,on='동 정보')
df_code
# Out:
#     동 정보  개수      총_생활인구_수   개수/생활인구  통계청행정동코드  행자부행정동코드 시도명 시군구명
# 0   가양1동  51  2.025333e+05  2.518105   1116064  11500603  서울  강서구
# 1    공항동  24  6.389930e+05  0.375591   1116069  11500620  서울  강서구
# 2   등촌1동  10  4.217219e+05  0.237123   1116052  11500520  서울  강서구
# 3   등촌2동  12  6.320865e+05  0.189847   1116053  11500530  서울  강서구
# 4   등촌3동  16  1.385180e+05  1.155085   1116054  11500535  서울  강서구
# 5   발산1동  19  6.665132e+05  0.285066   1116067  11500611  서울  강서구
# 6   방화1동  16  6.054130e+05  0.264282   1116070  11500630  서울  강서구
# 7   방화2동  14  5.938310e+05  0.235757   1116071  11500640  서울  강서구
# 8    염창동  16  7.947948e+05  0.201310   1116051  11500510  서울  강서구
# 9   우장산동  11  7.938244e+05  0.138570   1116074  11500615  서울  강서구
# 10  화곡1동  24  9.507398e+05  0.252435   1116073  11500540  서울  강서구
# 11  화곡2동   3  6.888078e+05  0.043554   1116057  11500550  서울  강서구
# 12  화곡3동   5  5.262232e+05  0.095017   1116058  11500560  서울  강서구
# 13  화곡4동   6  6.107031e+05  0.098247   1116059  11500570  서울  강서구
# 14  화곡6동  16  8.207713e+05  0.194939   1116061  11500591  서울  강서구
# 15  화곡8동   2  1.008358e+06  0.019834   1116063  11500593  서울  강서구
# 16  화곡본동   6  8.635931e+05  0.069477   1116055  11500590  서울  강서구

# %%
df_code.to_excel("동 기준 쓰레기통 및 생활인구수.xlsx")

# %%
last_df.sort_values('개수',ascending=False).head()
# Out:
#     동 정보  개수       총_생활인구_수   개수/생활인구
# 0   가양1동  51  202533.285714  2.518105
# 10  화곡1동  24  950739.814286  0.252435
# 1    공항동  24  638993.000000  0.375591
# 5   발산1동  19  666513.190476  0.285066
# 6   방화1동  16  605413.000000  0.264282

# %%
last_df.sort_values('총_생활인구_수',ascending=False).head()
# Out:
#     동 정보  개수      총_생활인구_수   개수/생활인구
# 15  화곡8동   2  1.008358e+06  0.019834
# 10  화곡1동  24  9.507398e+05  0.252435
# 16  화곡본동   6  8.635931e+05  0.069477
# 14  화곡6동  16  8.207713e+05  0.194939
# 8    염창동  16  7.947948e+05  0.201310

# %%
last_df.sort_values('개수/생활인구').head()

##화곡8동이 가장 적어서 화곡8동으로 하는 편이 나을듯.
# Out:
#     동 정보  개수      총_생활인구_수   개수/생활인구
# 15  화곡8동   2  1.008358e+06  0.019834
# 11  화곡2동   3  6.888078e+05  0.043554
# 16  화곡본동   6  8.635931e+05  0.069477
# 12  화곡3동   5  5.262232e+05  0.095017
# 13  화곡4동   6  6.107031e+05  0.098247

# %%
fig = plt.figure(figsize=(18,6))
ax=sns.barplot(x="동 정보",y="개수",data=last_df,color="salmon")

bg_color="#f1f1f1"
fig.patch.set_facecolor(bg_color)
fig.set_facecolor(bg_color)

for p in ax.patches:
    ax.annotate(format(p.get_height(),'.0f'),
               (p.get_x()+p.get_width()/2.,
               p.get_height()),
               ha='center',va='center',
               size=12,color='grey',
               xytext=(0,14),
               textcoords='offset points')
plt.xlabel("동 정보",size=14)
plt.ylabel("쓰레기통 수",size=14)
plt.title("동에 따른 가로 쓰레기통 개수",size=20,weight='bold',pad='13',loc='left')
plt.box(False)
plt.grid(True,axis='y',alpha=10,linestyle='--')
plt.show()

# %%
fig = plt.figure(figsize=(18,6))
ax=sns.barplot(x="동 정보",y="총_생활인구_수",data=last_df,color="salmon")

bg_color="#f1f1f1"
fig.patch.set_facecolor(bg_color)
fig.set_facecolor(bg_color)

for p in ax.patches:
    ax.annotate(format(p.get_height(),'.0f'),
               (p.get_x()+p.get_width()/2.,
               p.get_height()),
               ha='center',va='center',
               size=12,color='grey',
               xytext=(0,14),
               textcoords='offset points')
plt.xlabel("동 정보",size=14)
plt.ylabel("생활인구 수",size=14)
plt.title("동에 따른 생활인구 수",size=20,weight='bold',pad='15',loc='left')
plt.box(False)
plt.grid(True,axis='y',alpha=10,linestyle='--')
plt.show()

# %%
fig = plt.figure(figsize=(18,6))
ax=sns.barplot(x="동 정보",y="개수/생활인구",data=last_df,color="salmon")

bg_color="#f1f1f1"
fig.patch.set_facecolor(bg_color)
fig.set_facecolor(bg_color)

for p in ax.patches:
    ax.annotate(format(p.get_height(),'.0f'),
               (p.get_x()+p.get_width()/2.,
               p.get_height()),
               ha='center',va='center',
               size=12,color='grey',
               xytext=(0,14),
               textcoords='offset points')
plt.xlabel("동 정보",size=14)
plt.ylabel("비율",size=14)
plt.title("동에 따른 비율",size=20,weight='bold',pad='13',loc='left')
plt.box(False)
plt.grid(True,axis='y',alpha=10,linestyle='--')
plt.show()

# %%
last_df

fig,ax=plt.subplots(figsize=(12,6))
b1=plt.bar(last_df['동 정보'],last_df['개수'],color='r',width=0.5)
b2=plt.bar(last_df['동 정보'],last_df['총_생활인구_수'],color='b',width=0.5)

# %%
b2 = plt.bar(index + bar_width, df['shop B'], bar_width, alpha=0.4, color='blue', label='shop B')

b3 = plt.bar(index + 2 * bar_width, df['shop C'], bar_width, alpha=0.4, color='green', label='shop C')

# x축 위치를 정 가운데로 조정하고 x축의 텍스트를 year 정보와 매칭
plt.xticks(np.arange(bar_width, 4 + bar_width, 1), year)

# x축, y축 이름 및 범례 설정
plt.xlabel('year', size = 13)
plt.ylabel('revenue', size = 13)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-d4e0cdb4b9fb> in <module>
# ----> 1 b2 = plt.bar(index + bar_width, df['shop B'], bar_width, alpha=0.4, color='blue', label='shop B')
#       2
#       3 b3 = plt.bar(index + 2 * bar_width, df['shop C'], bar_width, alpha=0.4, color='green', label='shop C')
#       4
#       5 # x축 위치를 정 가운데로 조정하고 x축의 텍스트를 year 정보와 매칭
#
# NameError: name 'index' is not defined
