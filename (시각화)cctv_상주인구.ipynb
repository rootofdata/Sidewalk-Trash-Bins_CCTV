# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

# %%
import pandas as pd
df1 = pd.read_excel('C:/Users/dudtj/OneDrive - 숭실대학교 - Soongsil University/Desktop/CL/python/강서구 경진대회/data/공모전 데이터 모음/서울특별시 강서구 (안심이) CCTV 설치 현황.xlsx')
df2 = pd.read_excel('C:/Users/dudtj/OneDrive - 숭실대학교 - Soongsil University/Desktop/CL/python/강서구 경진대회/data/공모전 데이터 모음/강서구 상주인구(2020 1분기~2021 3분기 동정보 포함).xlsx')

# %%
#글씨설정
plt.rc("font",family="Malgun Gothic")
sns.set(font="Margun Gothic",rc={"axes.unicode_minus":False},style='darkgrid')
mpl.rc('font',family='Malgun Gothic')
plt.rcParams['axes.unicode_minus']=False

#맷플롯립 한글 설정
font_path = r'C:\Users\dudtj\OneDrive\Desktop\금융데이터\NanumFontSetup_TTF_ALL'
fontprop = fm.FontProperties(fname=font_path, size=18)

# %%
df1
# Out:
#       자치구                                              안심 주소 CCTV 용도  \
# 0     강서구                  P253001(A5002)_화곡1동 908-9(호돌이 공원)    도심공원
# 1     강서구                       P303005_화곡8동 892-17(모태어린이공원)    도심공원
# 2     강서구                        P263002_화곡2동 883-3 하마터어린이공원    도심공원
# 3     강서구                       P263001_화곡2동 845-19 뜸부기어린이공원    도심공원
# 4     강서구                       P253005_화곡1동 355-12(필마어린이공원)    도심공원
# ...   ...                                                ...     ...
# 2432  강서구  S222006(B1006)_방화3동 816 방화6단지 602동 앞(삼정초등학교)(보...   어린이안전
# 2433  강서구  S222006(B1006)_방화3동 816 방화6단지 602동 앞(삼정초등학교)(보...   어린이안전
# 2434  강서구               S222001(A1064)_(스쿨존)방화3동 798(삼정초등학교)   어린이안전
# 2435  강서구      S222001(A1064)_(스쿨존)방화3동 798(삼정초등학교)(보조1)정문방향   어린이안전
# 2436  강서구  S222001(A1064)_(스쿨존)방화3동 798(삼정초등학교)(보조2)도시개발6...   어린이안전
#
#              위도          경도  CCTV 수량      수정 일시  동정보
# 0     37.528107  126.845980        1 2021-01-29  NaN
# 1     37.529472  126.849621        1 2021-01-29  NaN
# 2     37.529998  126.853446        1 2021-01-29  NaN
# 3     37.530087  126.856926        1 2021-01-29  NaN
# 4     37.531600  126.838757        1 2021-01-29  NaN
# ...         ...         ...      ...        ...  ...
# 2432  37.579197  126.810640        1 2021-01-29  NaN
# 2433  37.579197  126.810640        1 2021-01-29  NaN
# 2434  37.579613  126.810660        1 2021-01-29  NaN
# 2435  37.579613  126.810660        1 2021-01-29  NaN
# 2436  37.579613  126.810660        1 2021-01-29  NaN
#
# [2437 rows x 8 columns]

# %%
df1=df1[df1["CCTV 용도"]=='쓰레기 무단투기']

# %%
address=['가양1동','가양2동','가양3동','공항동','등촌1동','등촌2동','등촌3동','발산1동','방화1동','방화2동','개화동','화곡동','등촌동','가양동'
         '방화2동','방화3동','염창동','우장산동','화곡1동','화곡2동','화곡3동','화곡4동','화곡6동','화곡8동','화곡본동','마곡동']

# %%
#for j in range(0,len(df1)):
#    for i in range(0,len(address)):
#        if address[i] in df1['안심 주소'][j]:
#            df1['동 정보'][j]=address[i]

# %%
df1
# Out:
#       자치구                                           안심 주소   CCTV 용도  \
# 2194  강서구                T255004(T9042)_화곡1동 914-39(무단투기)  쓰레기 무단투기
# 2195  강서구                 T215002(T9024)_화곡1동 937-7(무단투기)  쓰레기 무단투기
# 2196  강서구                T255005(T9043)_화곡1동 925-17(무단투기)  쓰레기 무단투기
# 2197  강서구                 T265003(T9041)_화곡동 856-21(무단투기)  쓰레기 무단투기
# 2198  강서구                 T265002(T9040)_화곡동 846-26(무단투기)  쓰레기 무단투기
# 2199  강서구                T285003(T9039)_화곡2동 791-12(무단투기)  쓰레기 무단투기
# 2200  강서구                T255002(T9032)_화곡1동 355-45(무단투기)  쓰레기 무단투기
# 2201  강서구                T285002(T9038)_화곡4동 782-16(무단투기)  쓰레기 무단투기
# 2202  강서구                T255001(T9031)_화곡1동 358-12(무단투기)  쓰레기 무단투기
# 2203  강서구                T305002(T9034)_화곡8동 397-48(무단투기)  쓰레기 무단투기
# 2204  강서구                 T305001(T9030)_화곡8동 154-8(무단투기)  쓰레기 무단투기
# 2205  강서구                T285001(T9037)_화곡4동 504-52(무단투기)  쓰레기 무단투기
# 2206  강서구                 T265001(T9036)_화곡4동 465-1(무단투기)  쓰레기 무단투기
# 2207  강서구                T305003(T9035)_화곡8동 408-49(무단투기)  쓰레기 무단투기
# 2208  강서구                T255003(T9033)_화곡1동 379-26(무단투기)  쓰레기 무단투기
# 2209  강서구          T185001(T9021)_화곡본동 105-242 노을공원(무단투기)  쓰레기 무단투기
# 2210  강서구                 T315004(T9029)_화곡동 98-229(무단투기)  쓰레기 무단투기
# 2211  강서구                T315002(T9027)_화곡본동 46-133(무단투기)  쓰레기 무단투기
# 2212  강서구                T275001(T9045)_화곡동 1013-18(무단투기)  쓰레기 무단투기
# 2213  강서구                 T315001(T9026)_화곡본동 29-40(무단투기)  쓰레기 무단투기
# 2214  강서구                T295001(T9044)_발산1동 718-14(무단투기)  쓰레기 무단투기
# 2215  강서구  T315003(T9028)_등촌2동 365-182(등촌로 51길 104)(무단투기)  쓰레기 무단투기
# 2216  강서구                T155001(T9020)_등촌1동 647-86(무단투기)  쓰레기 무단투기
# 2217  강서구                 T145002(T9019)_공항동 660-14(무단투기)  쓰레기 무단투기
# 2218  강서구                 T145001(T9018)_공항동 55-210(무단투기)  쓰레기 무단투기
# 2219  강서구                 T215003(T9025)_방화동 616-20(무단투기)  쓰레기 무단투기
# 2220  강서구                T215001(T9023)_방화2동 547-12(무단투기)  쓰레기 무단투기
# 2221  강서구                 T205001(T9022)_방화동 262-21(무단투기)  쓰레기 무단투기
#
#              위도          경도  CCTV 수량      수정 일시   동정보
# 2194  37.529114  126.844800        1 2021-01-29  화곡1동
# 2195  37.529304  126.839828        1 2021-01-29  화곡1동
# 2196  37.529650  126.842445        1 2021-01-29  화곡1동
# 2197  37.529940  126.853960        1 2021-01-29  화곡2동
# 2198  37.530319  126.856646        1 2021-01-29  화곡2동
# 2199  37.531060  126.859210        1 2021-01-29  화곡2동
# 2200  37.531166  126.839714        1 2021-01-29  화곡1동
# 2201  37.531403  126.863020        1 2021-01-29  화곡4동
# 2202  37.531830  126.839030        1 2021-01-29  화곡1동
# 2203  37.534676  126.848510        1 2021-01-29  화곡8동
# 2204  37.535934  126.851200        1 2021-01-29  화곡8동
# 2205  37.536083  126.860470        1 2021-01-29  화곡4동
# 2206  37.536420  126.854650        1 2021-01-29  화곡4동
# 2207  37.537506  126.845410        1 2021-01-29  화곡8동
# 2208  37.537678  126.838300        1 2021-01-29  화곡1동
# 2209  37.539675  126.843911        1 2021-01-29  화곡본동
# 2210  37.541866  126.844280        1 2021-01-29  화곡본동
# 2211  37.544310  126.848870        1 2021-01-29  화곡본동
# 2212  37.545480  126.835840        1 2021-01-29  화곡3동
# 2213  37.546684  126.847760        1 2021-01-29  화곡본동
# 2214  37.549814  126.835574        1 2021-01-29  발산1동
# 2215  37.549817  126.858125        1 2021-01-29  등촌2동
# 2216  37.552124  126.865720        1 2021-01-29  등촌1동
# 2217  37.556328  126.815810        1 2021-01-29   공항동
# 2218  37.558437  126.811710        1 2021-01-29   공항동
# 2219  37.564335  126.807260        1 2021-01-29   방화동
# 2220  37.569580  126.808840        1 2021-01-29  방화2동
# 2221  37.570960  126.813515        1 2021-01-29   방화동

# %%
df2.head()
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권 코드    상권 코드 명  총 상주인구 수  \
# 0     2021         3        A       골목상권  1000552  가로공원로76가길      2899
# 1     2021         2        A       골목상권  1000552  가로공원로76가길      2899
# 2     2021         1        A       골목상권  1000552  가로공원로76가길      3121
# 3     2020         4        A       골목상권  1000552  가로공원로76가길      3121
# 4     2020         3        A       골목상권  1000552  가로공원로76가길      3121
#
#    총 가구 수  동 정보
# 0    1343  화곡1동
# 1    1343  화곡1동
# 2    1397  화곡1동
# 3    1397  화곡1동
# 4    1397  화곡1동

# %%
groups = df1.groupby('동정보')
data1=groups.count() #평균
data1=data1.reset_index()
data1=data1[['동정보','CCTV 수량']]
data1.columns=['동 정보','개수']

# %%
df3=df2[df2["기준_년_코드"]==2021.0] #2021년
df3=df2[df2["기준_분기_코드"]==3]#df3은 21년,3분기 것만.

# %%
groups = df2.groupby('동 정보')
data2=groups.mean() #평균
data2=data2.reset_index()
data2=data2[['동 정보','총 상주인구 수']]

# %%
df5 = pd.read_excel('C:/Users/dudtj/OneDrive - 숭실대학교 - Soongsil University/Desktop/CL/python/강서구 경진대회/data/공모전 데이터 모음/행정동코드_매핑정보_2018_1.xlsx')
df5
# Out:
#     통계청행정동코드  행자부행정동코드 시도명 시군구명  동 정보
# 0    1116051  11500510  서울  강서구   염창동
# 1    1116052  11500520  서울  강서구  등촌1동
# 2    1116053  11500530  서울  강서구  등촌2동
# 3    1116054  11500535  서울  강서구  등촌3동
# 4    1116055  11500590  서울  강서구  화곡본동
# 5    1116057  11500550  서울  강서구  화곡2동
# 6    1116058  11500560  서울  강서구  화곡3동
# 7    1116059  11500570  서울  강서구  화곡4동
# 8    1116061  11500591  서울  강서구  화곡6동
# 9    1116063  11500593  서울  강서구  화곡8동
# 10   1116064  11500603  서울  강서구  가양1동
# 11   1116065  11500604  서울  강서구  가양2동
# 12   1116066  11500605  서울  강서구  가양3동
# 13   1116067  11500611  서울  강서구  발산1동
# 14   1116069  11500620  서울  강서구   공항동
# 15   1116070  11500630  서울  강서구  방화1동
# 16   1116071  11500640  서울  강서구  방화2동
# 17   1116072  11500641  서울  강서구  방화3동
# 18   1116073  11500540  서울  강서구  화곡1동
# 19   1116074  11500615  서울  강서구  우장산동

# %%
last_df=pd.merge(data1,data2,on='동 정보')
last_df['개수/상주인구']=last_df['개수']/last_df['총 상주인구 수']*10000
last_df
# Out:
#     동 정보  개수     총 상주인구 수    개수/상주인구
# 0    공항동   2  2796.142857   7.152710
# 1   등촌1동   1  2173.250000   4.601403
# 2   등촌2동   1  2691.523810   3.715367
# 3   발산1동   1  2880.857143   3.471189
# 4   방화2동   1  2643.892857   3.782302
# 5   화곡1동   6  2980.328571  20.132008
# 6   화곡2동   3  2929.678571  10.240031
# 7   화곡3동   1  2433.047619   4.110072
# 8   화곡4동   3  2527.600000  11.868967
# 9   화곡8동   3  3487.857143   8.601270
# 10  화곡본동   4  2976.035714  13.440699

# %%
df_code=pd.merge(last_df,df5,on='동 정보')
df_code
# Out:
#     동 정보  개수     총 상주인구 수    개수/상주인구  통계청행정동코드  행자부행정동코드 시도명 시군구명
# 0    공항동   2  2796.142857   7.152710   1116069  11500620  서울  강서구
# 1   등촌1동   1  2173.250000   4.601403   1116052  11500520  서울  강서구
# 2   등촌2동   1  2691.523810   3.715367   1116053  11500530  서울  강서구
# 3   발산1동   1  2880.857143   3.471189   1116067  11500611  서울  강서구
# 4   방화2동   1  2643.892857   3.782302   1116071  11500640  서울  강서구
# 5   화곡1동   6  2980.328571  20.132008   1116073  11500540  서울  강서구
# 6   화곡2동   3  2929.678571  10.240031   1116057  11500550  서울  강서구
# 7   화곡3동   1  2433.047619   4.110072   1116058  11500560  서울  강서구
# 8   화곡4동   3  2527.600000  11.868967   1116059  11500570  서울  강서구
# 9   화곡8동   3  3487.857143   8.601270   1116063  11500593  서울  강서구
# 10  화곡본동   4  2976.035714  13.440699   1116055  11500590  서울  강서구

# %%
df_code.to_excel("동 기준 CCTV 및 상주인구수.xlsx")

# %%
last_df.sort_values('개수',ascending=False).head()
# Out:
#     동 정보  개수     총 상주인구 수    개수/상주인구
# 5   화곡1동   6  2980.328571  20.132008
# 10  화곡본동   4  2976.035714  13.440699
# 6   화곡2동   3  2929.678571  10.240031
# 8   화곡4동   3  2527.600000  11.868967
# 9   화곡8동   3  3487.857143   8.601270

# %%
last_df.sort_values('총 상주인구 수',ascending=False).head()
# Out:
#     동 정보  개수     총 상주인구 수    개수/상주인구
# 9   화곡8동   3  3487.857143   8.601270
# 5   화곡1동   6  2980.328571  20.132008
# 10  화곡본동   4  2976.035714  13.440699
# 6   화곡2동   3  2929.678571  10.240031
# 3   발산1동   1  2880.857143   3.471189

# %%
last_df.sort_values('개수/상주인구').head()

##화곡8동이 가장 적어서 화곡8동으로 하는 편이 나을듯.
# Out:
#    동 정보  개수     총 상주인구 수   개수/상주인구
# 3  발산1동   1  2880.857143  3.471189
# 2  등촌2동   1  2691.523810  3.715367
# 4  방화2동   1  2643.892857  3.782302
# 7  화곡3동   1  2433.047619  4.110072
# 1  등촌1동   1  2173.250000  4.601403

# %%
fig = plt.figure(figsize=(18,6))
ax=sns.barplot(x="동 정보",y="개수",data=last_df,color="salmon")

bg_color="#f1f1f1"
fig.patch.set_facecolor(bg_color)
fig.set_facecolor(bg_color)

for p in ax.patches:
    ax.annotate(format(p.get_height(),'.0f'),
               (p.get_x()+p.get_width()/2.,
               p.get_height()),
               ha='center',va='center',
               size=12,color='grey',
               xytext=(0,14),
               textcoords='offset points')
plt.xlabel("동 정보",size=14)
plt.ylabel("CCTV 수",size=14)
plt.title("동에 따른 CCTV 수량",size=20,weight='bold',pad='13',loc='left')
plt.box(False)
plt.grid(True,axis='y',alpha=10,linestyle='--')
plt.show()

# %%
fig = plt.figure(figsize=(18,6))
ax=sns.barplot(x="동 정보",y="총 상주인구 수",data=last_df,color="salmon")

bg_color="#f1f1f1"
fig.patch.set_facecolor(bg_color)
fig.set_facecolor(bg_color)

for p in ax.patches:
    ax.annotate(format(p.get_height(),'.0f'),
               (p.get_x()+p.get_width()/2.,
               p.get_height()),
               ha='center',va='center',
               size=12,color='grey',
               xytext=(0,14),
               textcoords='offset points')
plt.xlabel("동 정보",size=14)
plt.ylabel("상주인구 수",size=14)
plt.title("동에 따른 상주인구 수",size=20,weight='bold',pad='15',loc='left')
plt.box(False)
plt.grid(True,axis='y',alpha=10,linestyle='--')
plt.show()

# %%
fig = plt.figure(figsize=(18,6))
ax=sns.barplot(x="동 정보",y="개수/상주인구",data=last_df,color="salmon")

bg_color="#f1f1f1"
fig.patch.set_facecolor(bg_color)
fig.set_facecolor(bg_color)

for p in ax.patches:
    ax.annotate(format(p.get_height(),'.5f'),
               (p.get_x()+p.get_width()/2.,
               p.get_height()),
               ha='center',va='center',
               size=12,color='grey',
               xytext=(0,14),
               textcoords='offset points')
plt.xlabel("동 정보",size=14)
plt.ylabel("비율",size=14)
plt.title("동에 따른 비율",size=20,weight='bold',pad='13',loc='left')
plt.box(False)
plt.grid(True,axis='y',alpha=10,linestyle='--')
plt.show()

# %%
last_df['총_상주인구_수[단위:1천명]']=last_df['총 상주인구 수']/1000
last_df
# Out:
#     동 정보  개수     총 상주인구 수    개수/상주인구  총_상주인구_수[단위:1천명]
# 0    공항동   2  2796.142857   7.152710          2.796143
# 1   등촌1동   1  2173.250000   4.601403          2.173250
# 2   등촌2동   1  2691.523810   3.715367          2.691524
# 3   발산1동   1  2880.857143   3.471189          2.880857
# 4   방화2동   1  2643.892857   3.782302          2.643893
# 5   화곡1동   6  2980.328571  20.132008          2.980329
# 6   화곡2동   3  2929.678571  10.240031          2.929679
# 7   화곡3동   1  2433.047619   4.110072          2.433048
# 8   화곡4동   3  2527.600000  11.868967          2.527600
# 9   화곡8동   3  3487.857143   8.601270          3.487857
# 10  화곡본동   4  2976.035714  13.440699          2.976036

# %%
ratio_df = last_df.sort_values('개수/상주인구')
ratio_df.rename(columns={'개수/상주인구':'개수/상주인구[단위:1만명]'},inplace=True)
ratio_df.reset_index(inplace=True)
ratio_df
# Out:
#     index  동 정보  개수     총 상주인구 수  개수/상주인구[단위:1만명]  총_상주인구_수[단위:1천명]
# 0       3  발산1동   1  2880.857143         3.471189          2.880857
# 1       2  등촌2동   1  2691.523810         3.715367          2.691524
# 2       4  방화2동   1  2643.892857         3.782302          2.643893
# 3       7  화곡3동   1  2433.047619         4.110072          2.433048
# 4       1  등촌1동   1  2173.250000         4.601403          2.173250
# 5       0   공항동   2  2796.142857         7.152710          2.796143
# 6       9  화곡8동   3  3487.857143         8.601270          3.487857
# 7       6  화곡2동   3  2929.678571        10.240031          2.929679
# 8       8  화곡4동   3  2527.600000        11.868967          2.527600
# 9      10  화곡본동   4  2976.035714        13.440699          2.976036
# 10      5  화곡1동   6  2980.328571        20.132008          2.980329

# %%
import numpy
from matplotlib import pyplot
fig,ax=plt.subplots(figsize=(12,6))
x=numpy.arange(len(last_df['동 정보']))

pyplot.bar(x-0.0,last_df['개수'],color='r',label='쓰레기통 개수',width=0.4)
pyplot.bar(x+0.2,last_df['총_상주인구_수[단위:1천명]'],label='상주인구(단위:1만명)',color='b',width=0.4)
pyplot.xticks(x,last_df['동 정보'])
pyplot.legend()
pyplot.xlabel('행정동')
pyplot.ylabel('수')
pyplot.title('상주인구 및 쓰레기통 개수')
# Out:
# Text(0.5, 1.0, '상주인구 및 쓰레기통 개수')

# %%
fig = plt.figure(figsize=(18,6))
ax=sns.barplot(x="동 정보",y="개수/상주인구[단위:1만명]",data=ratio_df,color="salmon")

bg_color="#f1f1f1"
fig.patch.set_facecolor(bg_color)
fig.set_facecolor(bg_color)

for p in ax.patches:
    ax.annotate(format(p.get_height(),'.5f'),
               (p.get_x()+p.get_width()/2.,
               p.get_height()),
               ha='center',va='center',
               size=12,color='grey',
               xytext=(0,14),
               textcoords='offset points')
plt.xlabel("동 정보",size=14)
plt.ylabel("비율",size=14)
plt.title("상주인구에 따른 CCTV 비율",size=20,weight='bold',pad='13',loc='left')
plt.box(False)
plt.grid(True,axis='y',alpha=10,linestyle='--')
plt.show()

# %%
import numpy
fig,ax=plt.subplots(figsize=(18,6))
x=numpy.arange(len(last_df['동 정보']))

plt.bar(x-0.2,last_df['개수'],color='r',label='cctv 개수',width=0.4)
plt.bar(x+0.2,last_df['총_상주인구_수[단위:1천명]'],label='상주인구(단위:1천명)',color='b',width=0.4)
plt.xticks(x,last_df['동 정보'])
plt.legend(loc='upper left')
plt.xlabel('행정동')
plt.ylabel('수치')
plt.title('상주인구 및 CCTV 개수',size=20,weight='bold')
plt.box(False)
plt.grid(True,axis='y',alpha=10,linestyle='--')
plt.show()

# %%
else_df=ratio_df[0:5]
fig = plt.figure(figsize=(12,6))
ax=sns.barplot(x="동 정보",y="개수/상주인구[단위:1만명]",data=else_df,color="salmon")

bg_color="#f1f1f1"
fig.patch.set_facecolor(bg_color)
fig.set_facecolor(bg_color)

for p in ax.patches:
    ax.annotate(format(p.get_height(),'.5f'),
               (p.get_x()+p.get_width()/2.,
               p.get_height()),
               ha='center',va='center',
               size=12,color='grey',
               xytext=(0,14),
               textcoords='offset points')
plt.xlabel("행정동",size=12)
plt.ylabel("CPP",size=14)
plt.title("행정동별 CPP지수(CCTV)",size=20,weight='bold',pad='13')
plt.box(False)
plt.grid(True,axis='y',alpha=10,linestyle='--')
plt.ylim(0,6)
plt.show()

# %%
ratio_df
# Out:
#     index  동 정보  개수     총 상주인구 수  개수/상주인구[단위:1만명]  총_상주인구_수[단위:1천명]
# 0       3  발산1동   1  2880.857143         3.471189          2.880857
# 1       2  등촌2동   1  2691.523810         3.715367          2.691524
# 2       4  방화2동   1  2643.892857         3.782302          2.643893
# 3       7  화곡3동   1  2433.047619         4.110072          2.433048
# 4       1  등촌1동   1  2173.250000         4.601403          2.173250
# 5       0   공항동   2  2796.142857         7.152710          2.796143
# 6       9  화곡8동   3  3487.857143         8.601270          3.487857
# 7       6  화곡2동   3  2929.678571        10.240031          2.929679
# 8       8  화곡4동   3  2527.600000        11.868967          2.527600
# 9      10  화곡본동   4  2976.035714        13.440699          2.976036
# 10      5  화곡1동   6  2980.328571        20.132008          2.980329
