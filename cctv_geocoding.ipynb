# %%
import pandas as pd
#matplotlib 패키지 한글 깨짐 처리 시작
import matplotlib.pyplot as plt
import platform
if platform.system() == 'Windows': #윈도우
        plt.rc('font', family='신명조체') 
plt.rcParams['axes.unicode_minus'] = False #한글 폰트 사용시 마이너스 폰트 깨짐 해결
#matplotlib 패키지 한글 깨짐 처리 끝

# %%
df = pd.read_csv('../서울 강서구 경진대회/data/서울특별시 (안심이) CCTV 설치 현황.csv',encoding='cp949')

# %%
df.head()
# Out:
#    자치구                  안심 주소 CCTV 용도         위도          경도  CCTV 수량  \
# 0  중랑구  방범382 혜화로12길 14-9 메인1    도심공원  37.589444  127.000588        1
# 1  중랑구   방범390 창의문로5나길 11 메인1    도심공원  37.591527  126.964637        1
# 2  중랑구    방범387 백석동길 20-3 메인1    도심공원  37.593207  126.966545        1
# 3  중랑구    방범375 율곡로29길 10 메인1    도심공원  37.574112  127.007482        1
# 4  중랑구     방범383 혜화로6길 32 메인1    도심공원  37.588087  127.001279        1
#
#         수정 일시
# 0  2021-11-16
# 1  2021-11-16
# 2  2021-11-16
# 3  2021-11-16
# 4  2021-11-16

# %%
df1=df[df["CCTV 용도"]=='쓰레기 무단투기']
df1=df1[df1["자치구"]=='강서구']
df1.reset_index(inplace=True)

# %%
df1
# Out:
#     index  자치구                                           안심 주소   CCTV 용도  \
# 0   49036  강서구                 T215003(T9025)_방화동 616-20(무단투기)  쓰레기 무단투기
# 1   49037  강서구                T215001(T9023)_방화2동 547-12(무단투기)  쓰레기 무단투기
# 2   49038  강서구                 T145002(T9019)_공항동 660-14(무단투기)  쓰레기 무단투기
# 3   49039  강서구                 T145001(T9018)_공항동 55-210(무단투기)  쓰레기 무단투기
# 4   49042  강서구                T295001(T9044)_발산1동 718-14(무단투기)  쓰레기 무단투기
# 5   49044  강서구                T275001(T9045)_화곡동 1013-18(무단투기)  쓰레기 무단투기
# 6   49046  강서구                T285001(T9037)_화곡4동 504-52(무단투기)  쓰레기 무단투기
# 7   49047  강서구                 T305001(T9030)_화곡8동 154-8(무단투기)  쓰레기 무단투기
# 8   49048  강서구                 T265003(T9041)_화곡동 856-21(무단투기)  쓰레기 무단투기
# 9   49049  강서구                T285002(T9038)_화곡4동 782-16(무단투기)  쓰레기 무단투기
# 10  49050  강서구                T255002(T9032)_화곡1동 355-45(무단투기)  쓰레기 무단투기
# 11  49430  강서구                 T215002(T9024)_화곡1동 937-7(무단투기)  쓰레기 무단투기
# 12  49432  강서구                 T265002(T9040)_화곡동 846-26(무단투기)  쓰레기 무단투기
# 13  49433  강서구                T255004(T9042)_화곡1동 914-39(무단투기)  쓰레기 무단투기
# 14  49436  강서구                T255001(T9031)_화곡1동 358-12(무단투기)  쓰레기 무단투기
# 15  49440  강서구                T305002(T9034)_화곡8동 397-48(무단투기)  쓰레기 무단투기
# 16  49443  강서구                 T265001(T9036)_화곡4동 465-1(무단투기)  쓰레기 무단투기
# 17  49445  강서구                T315002(T9027)_화곡본동 46-133(무단투기)  쓰레기 무단투기
# 18  49446  강서구                T255003(T9033)_화곡1동 379-26(무단투기)  쓰레기 무단투기
# 19  49449  강서구                 T315004(T9029)_화곡동 98-229(무단투기)  쓰레기 무단투기
# 20  49450  강서구          T185001(T9021)_화곡본동 105-242 노을공원(무단투기)  쓰레기 무단투기
# 21  49452  강서구                 T315001(T9026)_화곡본동 29-40(무단투기)  쓰레기 무단투기
# 22  49453  강서구  T315003(T9028)_등촌2동 365-182(등촌로 51길 104)(무단투기)  쓰레기 무단투기
# 23  49454  강서구                T255005(T9043)_화곡1동 925-17(무단투기)  쓰레기 무단투기
# 24  49455  강서구                T155001(T9020)_등촌1동 647-86(무단투기)  쓰레기 무단투기
# 25  49462  강서구                 T205001(T9022)_방화동 262-21(무단투기)  쓰레기 무단투기
# 26  49710  강서구                T305003(T9035)_화곡8동 408-49(무단투기)  쓰레기 무단투기
# 27  49712  강서구                T285003(T9039)_화곡2동 791-12(무단투기)  쓰레기 무단투기
#
#            위도          경도  CCTV 수량       수정 일시
# 0   37.564335  126.807260        1  2021-01-29
# 1   37.569580  126.808840        1  2021-01-29
# 2   37.556328  126.815810        1  2021-01-29
# 3   37.558437  126.811710        1  2021-01-29
# 4   37.549814  126.835574        1  2021-01-29
# 5   37.545480  126.835840        1  2021-01-29
# 6   37.536083  126.860470        1  2021-01-29
# 7   37.535934  126.851200        1  2021-01-29
# 8   37.529940  126.853960        1  2021-01-29
# 9   37.531403  126.863020        1  2021-01-29
# 10  37.531166  126.839714        1  2021-01-29
# 11  37.529304  126.839828        1  2021-01-29
# 12  37.530319  126.856646        1  2021-01-29
# 13  37.529114  126.844800        1  2021-01-29
# 14  37.531830  126.839030        1  2021-01-29
# 15  37.534676  126.848510        1  2021-01-29
# 16  37.536420  126.854650        1  2021-01-29
# 17  37.544310  126.848870        1  2021-01-29
# 18  37.537678  126.838300        1  2021-01-29
# 19  37.541866  126.844280        1  2021-01-29
# 20  37.539675  126.843911        1  2021-01-29
# 21  37.546684  126.847760        1  2021-01-29
# 22  37.549817  126.858125        1  2021-01-29
# 23  37.529650  126.842445        1  2021-01-29
# 24  37.552124  126.865720        1  2021-01-29
# 25  37.570960  126.813515        1  2021-01-29
# 26  37.537506  126.845410        1  2021-01-29
# 27  37.531060  126.859210        1  2021-01-29

# %%
#pip install folium

# %%
import folium
import pandas as pd

x=[]
y=[]
for i in range(len(df1['위도'])):
    if df1['위도'][i]==0.0 or df1['경도'][i]==0.0:
        pass
    else:
        x.append(df1['위도'][i])
        y.append(df1['경도'][i])
print(len(x))
# Out:
# 28

# %%
import folium
map_osm = folium.Map(lacation=[x[13],y[13]],zoom_start=10000000)
for i in range(len(x)):
    folium.Marker([x[i],y[i]],popup='강서구 cctv_%d'%i,icon=folium.Icon(color='blue',icon='info-sign')).add_to(map_osm)


map_osm.save('서울특별시 강서구 cctv.html')

# %%
#import folium

#center = (df['위도'].mean(), df['경도'].mean())
#zoom = 13

#m = folium.Map(location = center, 
#               zoom_start = zoom,
#               tiles = 'http://api.vworld.kr/req/wmts/1.0.0/AIzaSyDeC28v5SGx9Y6UMUsbgoUvx8dgTNcBQEQ/Base/{z}/{y}/{x}.png',
#               attr = '강서구'
#              )
#for index, row in df.iterrows():
#    folium.Marker([row['위도'], row['경도']]).add_to(m)

#m
